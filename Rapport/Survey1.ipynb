# %% [markdown]
# One of the first things we did, paralell with our first interview, was send out a survey. We did this to empathize and really get to know our problem owner. We wanted to know how they got around the city and how they experienced that mode of transportation. For the full survey result please see __[Link](https://docs.google.com/forms/d/1FhLoJtxtYQf1nxCZZqXZqHyzYyEoKQNaWXmvmmy7zmw/edit#responses)__

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-1.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-2.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-3.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-4.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-7.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-8.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-5.png", width=500, height=500)

# %%
from IPython.display import Image

Image(filename="it1-emp-enkat-6.png", width=500, height=500)
